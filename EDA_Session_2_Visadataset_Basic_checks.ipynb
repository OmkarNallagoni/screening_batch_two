# %% [markdown]
# **Import packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the data**

# %%
visa_df=pd.read_csv('Visadataset.csv')
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **head**

# %%
visa_df.head(10)  # by default top 5 rows
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# **tail**

# %%
# dataframe name is : visa_df
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# **shape**

# %%
visa_df.shape

# dataframe is a matrix kind of representation
# It has rows and columns (m,n)
# rows=25480, columns=12
# the ans in tuple
# Out:
# (25480, 12)

# %%
print("the number of rows are:",visa_df.shape[0])
print("the number of columns are:",visa_df.shape[1])
# Out:
# the number of rows are: 25480
# the number of rows are: 12

# %% [markdown]
# **size**
#
# - size means number of fields in a given dataframe
#
# - it is multiplication of rows and columns
#
# - we have 25480 rows and 12 columns so that 25480X12=305760

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %% [markdown]
# **columns**

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(visa_df.columns)
# Out:
# 12

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(visa_df.columns)
# The index type can convert into list type
# by applying list type cast
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# **dtypes**
#
# - object means categorical data type
#
# - the data types given in series type

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task-1**
#
# **Extract categorical columns-numerical columns seperately**
#
# - Convert series type to dictionary
#
# - So that it will give key-value pair
#
# - iterate using for loop
#
# - apply the condition on value equal to object then extract corresponding key

# %%
dtypes=dict(visa_df.dtypes)

# %%
dtypes=dict(visa_df.dtypes)
cat_list=[]
for key,value in dtypes.items():
    if value=='object':
        cat_list.append(value)

# %%
dtypes=dict(visa_df.dtypes)
cat_list=[key for key,value in dtypes.items() if value=='object']
num_list=[key for key,value in dtypes.items() if value!='object']

# %%
cat_list
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
# df1
pd.DataFrame(cat_list,columns=['Object type'])
# Out:
#              Object type
# 0                case_id
# 1              continent
# 2  education_of_employee
# 3     has_job_experience
# 4  requires_job_training
# 5   region_of_employment
# 6           unit_of_wage
# 7     full_time_position
# 8            case_status

# %%
pd.DataFrame(num_list,columns=['Numerical type'])
# Out:
#     Numerical type
# 0  no_of_employees
# 1      yr_of_estab
# 2  prevailing_wage

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# $Method-1$

# %% [markdown]
# - any series can convert into dictionary
#
# - any dictionary can make into list
#
# - any list can make into dataframe

# %%
dtypes1=dict(visa_df.dtypes)
keys=dtypes1.keys()
values=dtypes1.values()
dtype_df=pd.DataFrame(zip(keys,values),columns=['Column','Data type'])
# Out:
#                    Column Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# $Method-2$
#
# - Every series have two methods
#
# - One is keys
#
# - second one is values

# %%
keys=visa_df.dtypes.keys()

# %%
values=visa_df.dtypes.values

# %%
pd.DataFrame(zip(keys,values))
# Out:
#                         0        1
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %% [markdown]
# **Select dtypes**

# %%
# It will give a catgorical columns dataframe
visa_df.select_dtypes(include='object') 

cat_col=visa_df.select_dtypes(include='object').columns
num_col=visa_df.select_dtypes(exclude='object').columns
cat_col,num_col
# Out:
# (Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'),
#  Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'))

# %% [markdown]
# **isnull**
#
# - isnull means we are asking a qn to the computer
#
# - if that particular filed has value or do not have value
#
# - if value present represnt as False
#
# - if value not present as True

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# It will give column wise missing value
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# **info**

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# **take**
#
# - we know that head will give top 5
#
# - tail will give last 5
#
# - but what if we want specifc rows or specific columns
#
# - then we can use **take** method
#
# - take method take a list of values that represents index
#
# - by default axis=0, which represnts rows
#
# - if we provide axis=1 , which represnts columns

# %%
visa_df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300],axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 visa_df.take([100,200,300],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:874, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
visa_df.take([5,8,10],axis=1)
# Out:
#        no_of_employees  prevailing_wage full_time_position
# 0                14513         592.2029                  Y
# 1                 2412       83425.6500                  Y
# 2                44444      122996.8600                  Y
# 3                   98       83434.0300                  Y
# 4                 1082      149907.3900                  Y
# ...                ...              ...                ...
# 25475             2601       77092.5700                  Y
# 25476             3274      279174.7900                  Y
# 25477             1121      146298.8500                  N
# 25478             1918       86154.7700                  Y
# 25479             3195       70876.9100                  Y
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100:105])
# Out:
#   Cell In[58], line 1
#     visa_df.take([100:105])
#                      ^
# SyntaxError: invalid syntax

# %%
visa_df.take([5,8,10],axis=1).take([100,200,300],axis=0)
# Out:
#      no_of_employees  prevailing_wage full_time_position
# 100             2227         28243.79                  Y
# 200             3282         74441.11                  Y
# 300             3268        101371.21                  Y

# %%
# Whever you open a notebook freshly
# make sure 
# import the packages 
# and read the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv('Visadataset.csv')
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %% [markdown]
# - Take has a draw back it can retrive either rows or columns only
#
# - if we want to both use iloc or loc indexing
#
# - function or method has () , but indexing has []

# %%
visa_df.iloc

# %%
visa_df.take
# Out:
# <bound method NDFrame.take of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# visa_df.iloc[<rows>,<columns>]

# rows we can do slice

# columns we can do slice

# visa_df.iloc[start:stop:step,start:stop:step]

# %%
visa_df.iloc[100:105,5:8]
# rows 100 to 104  columns 5th to 7th
# Out:
#      no_of_employees  yr_of_estab region_of_employment
# 100             2227         2007            Northeast
# 101              334         2007              Midwest
# 102              224         2008              Midwest
# 103              367         1982                 West
# 104              306         2003            Northeast

# %%
visa_df.iloc[100:103]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 101  EZYV102      Asia              Master's                  Y
# 102  EZYV103      Asia            Bachelor's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 101                     N              334         2007              Midwest
# 102                     N              224         2008              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 101         43421.88         Year                  Y   Certified
# 102         80253.78         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[[100,200,300],[5,7,9]]
# Out:
#      no_of_employees region_of_employment unit_of_wage
# 100             2227            Northeast         Year
# 200             3282                 West         Year
# 300             3268              Midwest         Year

# %%
visa_df.iloc[:,1] # Continent column
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[1]]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
to get only 1 column or 1 row need to use specific index instead of slicing sir??

# %%
visa_df.iloc[100:105,5:8] 
visa_df.iloc[100:103] # 100 to 102 rows all the columns
visa_df.iloc[[100,200,300]] # 100,200,300 rows and all the columns
visa_df.iloc[[100,200,300],[5,7,9]] # 5,7,9 columns with 100,200,300 rows
# one row with all columns
visa_df.iloc[:,1]  # One column all the rows series type
visa_df.iloc[:,[1]] # one column all the rows dataframe type

# %%
list(visa_df.columns).index('prevailing_wage')
# Out:
# 8

# %%
visa_df.iloc[:,8]
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %% [markdown]
# **loc**
#
# - iloc and loc both are trying to retrive rows and columns
#
# - but for columns iloc expect index
#
# - loc expect direct column names

# %%
visa_df.loc[:,['prevailing_wage','continent']]
# Out:
#        prevailing_wage continent
# 0             592.2029      Asia
# 1           83425.6500      Asia
# 2          122996.8600      Asia
# 3           83434.0300      Asia
# 4          149907.3900    Africa
# ...                ...       ...
# 25475       77092.5700      Asia
# 25476      279174.7900      Asia
# 25477      146298.8500      Asia
# 25478       86154.7700      Asia
# 25479       70876.9100      Asia
#
# [25480 rows x 2 columns]

# %% [markdown]
# **multiple values means always think about list**
#
# **any parameter says index or array means , it is expecting a list of values**
#
# **the index values can represnt as list, numpy array or tensor**
